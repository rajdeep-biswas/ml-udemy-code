# %%
import pandas as pd

# %%
dataset = pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
X = dataset[["Age", "EstimatedSalary"]]
y = dataset[["Purchased"]]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# without feature scaling

y_pred = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2).fit(X_train, y_train).predict(X_test)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# with feature scaling

y_pred = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2).fit(X_train, y_train).predict(scaler.transform(X_test))
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from sklearn.metrics import confusion_matrix

# %%
# without feature scaling

confusion_matrix(y_test, y_pred)
# Out:
# array([[57,  6],
#        [18, 19]])

# %%
from sklearn.metrics import accuracy_score

# %%
# without feature scaling

accuracy_score(y_test, y_pred)
# Out:
# 0.76

# %%
# with feature scaling

confusion_matrix(y_test, y_pred)
# Out:
# array([[65,  4],
#        [ 5, 26]])

# %%
# without feature scaling

accuracy_score(y_test, y_pred)
# Out:
# 0.91

# %%
X_train
# Out:
# array([[-0.99977981,  0.50902932],
#        [-1.37399558, -0.13143427],
#        [ 1.05840694, -0.15928051],
#        [ 1.99394637,  1.65072527],
#        [ 0.40352934,  0.06348943],
#        [-0.81267192, -0.66051288],
#        [ 0.02931357, -0.27066548],
#        [ 0.02931357, -0.54912791],
#        [ 0.40352934, -0.46558918],
#        [ 1.33906877,  2.20765013],
#        [-0.06424037,  0.25841313],
#        [-0.25134826,  0.73179926],
#        [-1.74821135, -1.38451519],
#        [-0.25134826,  0.11918192],
#        [-0.25134826,  0.1748744 ],
#        [-1.09333375, -1.55159265],
#        [ 1.90039243,  0.67610678],
#        [-1.28044164, -0.43774294],
#        [ 1.90039243, -1.32882271],
#        [-0.15779432, -0.21497299],
#        [ 0.964853  ,  0.70395302],
#        [ 0.12286751, -0.79974409],
#        [ 1.52617666,  1.03810793],
#        [-0.15779432, -0.57697415],
#        [-1.09333375, -0.77189785],
#        [-1.09333375,  1.31657036],
#        [ 0.21642146,  0.11918192],
# ...
